# %%
import primer3
from Bio import SeqIO
from Bio.Seq import Seq
import re
from matplotlib import pyplot as plt
from typing import Dict, List
root_dir="/home/lshas17/"
import pandas as pd
from itertools import product
from sys import path
path.insert(1, f'{root_dir}/HandyAmpliconTool/scripts/')
from data_classes import BlastResult, PrimerPair, Primer

# %% [markdown]
# primer3 is a package in primer3-py - a python wrapper for primer3 engine
#
# https://libnano.github.io/primer3-py
#
# https://github.com/primer3-org/primer3

# %% [markdown]
# Load reference data and existing primers

# %%
#Load reference fasta file
ref_seq=""
for seq in SeqIO.parse(f'{root_dir}/HandyAmpliconTool/test_data/inputs/GCA_000195995.1_for_VCFs.fasta', "fasta"):
    if seq.id=="AL513382_143N_pHCM1_120N_pHCM2":
        ref_seq=seq

#Load existing primers from fasta file
existing_primers={}
for record in SeqIO.parse(f'{root_dir}/HandyAmpliconTool/test_data/inputs/existing_primers.fasta', "fasta"):
    existing_primers[record.id]=str(record.seq)

# %% [markdown]
# Load the VCF containing the genotype and species defining SNPS

# %%
vcf_file_name=f'{root_dir}/HandyAmpliconTool/test_data/outputs/2_3_1/snps.vcf'
header_rows=0
for line in open(vcf_file_name):
    if line[0]=="#":
        header_rows+=1
vcf_data=pd.read_csv(vcf_file_name, sep="\t", header=0, skiprows=header_rows-1) # -1 because header row also starts with #CHROM

# %% [markdown]
# Load functions that create and process inputs from the primer3 functions

# %%
def add_fixed_primer(for_seq: str, rev_seq:str, template: str):
    global_args={
        'PRIMER_OPT_SIZE': 20,
        'PRIMER_OPT_TM': 60.0,
        'PRIMER_MIN_TM': 50.0,
        'PRIMER_MAX_TM': 70.0,
        'PRIMER_PRODUCT_SIZE_RANGE': f'100-{len(template)}'}
    if for_seq!=None:
        global_args['SEQUENCE_PRIMER']=for_seq
    if rev_seq!=None:
        global_args['SEQUENCE_PRIMER_REVCOMP']=rev_seq
    return global_args

def has_homodimers(forward_seq, reverse_seq) -> bool:
    thermoresult_forward=primer3.bindings.calc_homodimer(forward_seq)
    thermoresult_reverse=primer3.bindings.calc_homodimer(reverse_seq)
    if (thermoresult_forward.structure_found and thermoresult_forward.tm>10) or \
            (thermoresult_reverse.structure_found and thermoresult_reverse.tm>10):
        return True
    else:
        return False 
def check_heterodimers(forward_seq, reverse_seq):
    global existing_primers
    total_structures=0
    for primer in existing_primers:
        if primer.find("Forward")>-1:
            forward_result=primer3.bindings.calc_heterodimer(reverse_seq, existing_primers[primer])
            total_structures+=1 if forward_result.structure_found and forward_result.tm>10 else 0
        else:
            reverse_result=primer3.bindings.calc_heterodimer(forward_seq, existing_primers[primer])
            total_structures+=1 if reverse_result.structure_found and reverse_result.tm>10 else 0
    return total_structures

def process_p3_output(output: Dict, id_prefix: str) -> List[PrimerPair]:
    primer_pairs=len(output["PRIMER_PAIR"])
    result: List[PrimerPair]=[]
    for i in range(0,primer_pairs):
        forward=Primer(seq=output[f'PRIMER_LEFT_{str(i)}_SEQUENCE'],
                       g_c=output[f'PRIMER_LEFT_{str(i)}_GC_PERCENT'],
                       t_m=output[f'PRIMER_LEFT_{str(i)}_TM'])
        reverse=Primer(seq=output[f'PRIMER_RIGHT_{str(i)}_SEQUENCE'],
                       g_c=output[f'PRIMER_RIGHT_{str(i)}_GC_PERCENT'],
                       t_m=output[f'PRIMER_RIGHT_{str(i)}_TM'])
        new_pair=PrimerPair(name=id_prefix, forward=forward, reverse=reverse)
        new_pair.penalty=output[f'PRIMER_PAIR_{str(i)}_PENALTY']
        if not has_homodimers(forward.seq, reverse.seq) and check_heterodimers(forward.seq, reverse.seq)==0:
            result.append(new_pair)
            #output[f'PRIMER_PAIR_{str(i)}_PRODUCT_SIZE']
            print(f'LEFT: {output["PRIMER_LEFT_EXPLAIN"]}')
            print(f'RIGHT: {output["PRIMER_RIGHT_EXPLAIN"]}')
            print(f'PAIR: {output["PRIMER_PAIR_EXPLAIN"]}')
            print("\n")
    return result

# %%
unique_new_primer_pairs: List[PrimerPair]=[]
existing_sequences=set()
for pair in new_primer_pairs:
    if pair.forward.seq not in existing_sequences and pair.reverse.seq not in existing_sequences:
        unique_new_primer_pairs.append(pair)
        existing_sequences.add(pair.forward.seq)
        existing_sequences.add(pair.reverse.seq)

# %%
min_penalty_pairs[key].name
# Out:
# '2.3.1_4105815_both_fixed'

# %%
with open(f'{root_dir}/HandyAmpliconTool/test_data/outputs/temp.tsv', "w") as output:
    output.write("Name\tStart\tEnd\tLength\tForward\tTm\tReverse\tTm\n")
    for i, key in enumerate(min_penalty_pairs):
        pair=min_penalty_pairs[key]
        output.write( "\t".join( [ str(f) for f in [min_penalty_pairs[key].name,
                       pair.forward.ref_start,
                       pair.reverse.ref_end,
                       pair.length,
                       pair.forward.seq,
                       pair.forward.t_m,
                       pair.reverse.seq,
                       pair.reverse.t_m,
                       key
                       ]  ] ) +"\n")

# %%
#check primers vs reference with existing primers
pairs_to_take=10

with open(f'{root_dir}/HandyAmpliconTool/test_data/inputs/temp.fasta', "w") as temp_fasta:
    for key in existing_primers:
        temp_fasta.write(f'>{key}'+"\n")
        temp_fasta.write(f'{existing_primers[key]}'+"\n")
    #prioritise the pairs with both ends on Serovar SNPs
    serovar_both_sides=sorted( [f for f in unique_new_primer_pairs if f.name.find("both_fixed")>-1], key=lambda x: x.penalty)

    min_penalty_pairs=sorted( unique_new_primer_pairs, key=lambda x: x.penalty)[0: min(len(unique_new_primer_pairs), pairs_to_take)] + \
                        serovar_both_sides[0: min(len(unique_new_primer_pairs), pairs_to_take)]
    min_penalty_pairs=dict([ (pair.uuid, pair) for pair in min_penalty_pairs] )

    for pair_uuid, pair in min_penalty_pairs.items():
        temp_fasta.write(f'>{pair.uuid}_Forward'+"\n")
        temp_fasta.write(pair.forward.seq +"\n")
        temp_fasta.write(f'>{pair.uuid}_Reverse'+"\n")
        temp_fasta.write(pair.reverse.seq+"\n")

   
sensitive_search=!/home/lshas17/utilities/quickblast.sh /home/lshas17/HandyAmpliconTool/test_data/inputs/temp.fasta ~/HandyAmpliconTool/test_data/inputs/GCA_000195995.1_for_VCFs.fasta 5
blast_results: List[BlastResult]=[]
for i, item in enumerate(sensitive_search):
    new_result=BlastResult.from_blast_line(item)
    blast_results.append(new_result)
print(blast_results)
with open(f'{root_dir}/HandyAmpliconTool/test_data/inputs/blast_results.tsv', "w") as output:
    ##Check the blat results to idenify primers from outside pair that allign within the pair product
    for i, result_outer in enumerate(blast_results):
        outer_seq={"uuid": result_outer.qseqid.replace("_Forward","").replace("_Reverse",""), 
                    "orientation": "forward" if result_outer.qseqid.find("Forward")>-1 else "reverse"}
        # output.write("\t".join( [str(f) for f in [result_outer.sseqid, result_outer.sstart, result_outer.send, result_outer.qseqid]]  )+"\n" )
        # continue

        for j, result_inner in enumerate(blast_results[i+1:]):
            inner_seq={"uuid": result_inner.qseqid.replace("_Forward","").replace("_Reverse",""), 
                    "orientation": "forward" if result_inner.qseqid.find("Forward")>-1 else "reverse"}
            #conditions that need to be met:
            #1. length between matches < maximum interval between primers
            #2. the aligned primers are not the same sequence
            if outer_seq["uuid"] not in min_penalty_pairs:
                continue
            else:
                if outer_seq["orientation"]=="forward":
                    length=min_penalty_pairs[outer_seq["uuid"]].forward.length
                    if result_outer.send-result_outer.sstart==length-1:
                        min_penalty_pairs[outer_seq["uuid"]].forward.ref_start=result_outer.sstart+1
                else:
                    length=min_penalty_pairs[outer_seq["uuid"]].reverse.length
                    if result_outer.sstart-result_outer.send==length-1:
                        min_penalty_pairs[outer_seq["uuid"]].reverse.ref_start=result_outer.sstart+1



                #     if (result_outer.send-result_outer.sstart)>min_penalty_pairs[outer_seq["uuid"]].forward.ref_end-min_penalty_pairs[outer_seq["uuid"]].forward.ref_start:
                #         min_penalty_pairs[outer_seq["uuid"]].forward.ref_start=result_outer.ref_start
                #         min_penalty_pairs[outer_seq["uuid"]].forward.ref_end=result_outer.ref_end
                # else:
                #     if (result_outer.send-result_outer.sstart)>min_penalty_pairs[outer_seq["uuid"]].reverse.ref_end-min_penalty_pairs[outer_seq["uuid"]].reverse.ref_start:
                #         min_penalty_pairs[outer_seq["uuid"]].reverse.ref_start=result_outer.ref_start
                #         min_penalty_pairs[outer_seq["uuid"]].reverse.ref_start=result_outer.ref_end

                # if outer_seq["uuid"]=="11215168-7bc8-4f7f-8a26-eecfe75e441c" or inner_seq["uuid"]=="11215168-7bc8-4f7f-8a26-eecfe75e441c":
                #     a=1            
                # if outer_seq["orientation"]==inner_seq["orientation"]:
                #     #both sequences amplify in same direction, so they can't create a amplification product
                #     continue
                # elif (outer_seq["orientation"]=="forward" and result_outer.is_flipped) or \
                #             (outer_seq["orientation"]=="reverse" and not result_outer.is_flipped) or \
                #             (inner_seq["orientation"]=="forward" and result_inner.is_flipped) or \
                #             (inner_seq["orientation"]=="reverse" and not result_inner.is_flipped) :
                #     #at least one of the two sequences don't align in the correct orientation, so they can't create a amplification product
                #     continue
                # elif abs(result_outer.sstart-result_inner.sstart)<interval_len:
                #     #sequences align to correct strands and are close enough to interact
                #     output.write("\t".join(  ["NC_003198.1", str(result_outer.sstart), str(result_outer.send), result_outer.qseqid] ) +"\n"  )
                #     output.write("\t".join(  ["NC_003198.1", str(result_inner.sstart), str(result_inner.send), result_inner.qseqid] ) +"\n"  )
                
# with open(f'{root_dir}/HandyAmpliconTool/test_data/inputs/blast_results.tsv', "w") as output:
#     for id, pair in min_penalty_pairs.items():
#         output.write(pair.value+"\n")
# Out:
# [<data_classes.BlastResult object at 0x7f4fb00e8fd0>, <data_classes.BlastResult object at 0x7f4f5bdb93f0>, <data_classes.BlastResult object at 0x7f4f5bdb9210>, <data_classes.BlastResult object at 0x7f4f5bdb9240>, <data_classes.BlastResult object at 0x7f4f5bdb9300>, <data_classes.BlastResult object at 0x7f4f5bdb92d0>, <data_classes.BlastResult object at 0x7f4f5bdb92a0>, <data_classes.BlastResult object at 0x7f4f5bdbb3d0>, <data_classes.BlastResult object at 0x7f4f5bdb9360>, <data_classes.BlastResult object at 0x7f4f5bdb8c70>, <data_classes.BlastResult object at 0x7f4f5bdb93c0>, <data_classes.BlastResult object at 0x7f4f5bdb9390>, <data_classes.BlastResult object at 0x7f4f5bdb8c10>, <data_classes.BlastResult object at 0x7f4f5bdbb3a0>, <data_classes.BlastResult object at 0x7f4f5bdbb370>, <data_classes.BlastResult object at 0x7f4f5bdbb340>, <data_classes.BlastResult object at 0x7f4f5bdbb310>, <data_classes.BlastResult object at 0x7f4f5bdbb2e0>, <data_classes.BlastResult object at 0x7f4f5bdbb2b0>, <data_classes.BlastResult object at 0x7f4f5bdbb280>, <data_classes.BlastResult object at 0x7f4f5bdbb250>, <data_classes.BlastResult object at 0x7f4f5bdbb220>, <data_classes.BlastResult object at 0x7f4f5bdbb1f0>, <data_classes.BlastResult object at 0x7f4f5bdbb1c0>, <data_classes.BlastResult object at 0x7f4f5bdbb190>, <data_classes.BlastResult object at 0x7f4f5bdbb160>, <data_classes.BlastResult object at 0x7f4f5bdbb130>, <data_classes.BlastResult object at 0x7f4f5bdb9900>, <data_classes.BlastResult object at 0x7f4f5bdb98d0>, <data_classes.BlastResult object at 0x7f4f5bdb98a0>, <data_classes.BlastResult object at 0x7f4f5bdb9870>, <data_classes.BlastResult object at 0x7f4f5bdb9840>, <data_classes.BlastResult object at 0x7f4f5bdb9810>, <data_classes.BlastResult object at 0x7f4f5bdb97e0>, <data_classes.BlastResult object at 0x7f4f5bdb97b0>, <data_classes.BlastResult object at 0x7f4f5bdb9780>, <data_classes.BlastResult object at 0x7f4f5bdb9750>, <data_classes.BlastResult object at 0x7f4f5bdb9720>, <data_classes.BlastResult object at 0x7f4f5bdb96f0>, <data_classes.BlastResult object at 0x7f4f5bdb9660>, <data_classes.BlastResult object at 0x7f4f5bdb82b0>, <data_classes.BlastResult object at 0x7f4f5bdb80a0>, <data_classes.BlastResult object at 0x7f4f5bdb8220>, <data_classes.BlastResult object at 0x7f4f5bdb8250>, <data_classes.BlastResult object at 0x7f4f5bdb8280>, <data_classes.BlastResult object at 0x7f4f5bdb9600>, <data_classes.BlastResult object at 0x7f4f5bdb9630>, <data_classes.BlastResult object at 0x7f4f5bdb9690>, <data_classes.BlastResult object at 0x7f4f5bdb96c0>, <data_classes.BlastResult object at 0x7f4f5bdb8130>, <data_classes.BlastResult object at 0x7f4f5bdb81f0>, <data_classes.BlastResult object at 0x7f4f5bdb81c0>, <data_classes.BlastResult object at 0x7f4f5bdb8160>, <data_classes.BlastResult object at 0x7f4f5bdb8100>, <data_classes.BlastResult object at 0x7f4f5bdb8190>, <data_classes.BlastResult object at 0x7f4f5bdb9930>, <data_classes.BlastResult object at 0x7f4f5bdb9960>, <data_classes.BlastResult object at 0x7f4f5bdb9990>, <data_classes.BlastResult object at 0x7f4f5bdb99c0>, <data_classes.BlastResult object at 0x7f4f5bdb99f0>, <data_classes.BlastResult object at 0x7f4f5bdb9a20>, <data_classes.BlastResult object at 0x7f4f5bdb9a50>, <data_classes.BlastResult object at 0x7f4f5bdb9a80>, <data_classes.BlastResult object at 0x7f4f5bdb9ab0>, <data_classes.BlastResult object at 0x7f4f5bdb9ae0>, <data_classes.BlastResult object at 0x7f4f5bdb9b10>, <data_classes.BlastResult object at 0x7f4f5bdb9b40>, <data_classes.BlastResult object at 0x7f4f5bdb9b70>, <data_classes.BlastResult object at 0x7f4f5bdb9ba0>, <data_classes.BlastResult object at 0x7f4f5bdb9bd0>, <data_classes.BlastResult object at 0x7f4f5bdb9c00>, <data_classes.BlastResult object at 0x7f4f5bdb9c30>, <data_classes.BlastResult object at 0x7f4f5bdb9c60>, <data_classes.BlastResult object at 0x7f4f5bdb9c90>, <data_classes.BlastResult object at 0x7f4f5bdb9cc0>, <data_classes.BlastResul ...

# %%
target_lineage="2.3.1"
interval_len=1500
min_interval_len=200
target_lineage_index=vcf_data.index[ [f for f in vcf_data.index if vcf_data.loc[f, "ID"].find(target_lineage)>-1]  ]

new_primer_pairs: List[PrimerPair] = []

for index in target_lineage_index:
    snp_position=vcf_data.loc[index, "POS"]
    valid_range=range(snp_position-interval_len, snp_position+interval_len)
    interval_indices=[ f for f in vcf_data.index if vcf_data.loc[f, "POS"] in valid_range ]

    interval_left_serovar_snps=[f for f in interval_indices if vcf_data.loc[f,"ID"].find("Serovar")>-1 and f<index ]
    interval_right_serovar_snps=[f for f in interval_indices if vcf_data.loc[f,"ID"].find("Serovar")>-1 and f>index]
    if len(interval_left_serovar_snps)>0 and len(interval_right_serovar_snps)>0:
        print(f'SNP at {snp_position} has serovar SNPs left and right of genotype SNP')
    elif len(interval_right_serovar_snps)>0:
        print(f'SNP at {snp_position} has serovar SNPs right of genotype SNP')
    elif len(interval_left_serovar_snps):
        print(f'SNP at {snp_position} has serovar SNPs left of genotype SNP')
    else:
        print(f'SNP at {snp_position} has no serovar SNPs within {str(interval_len)} region')


#four three cases: 
# 1 - left and right serovar SNPs anchored primers
# 2 - left serovar anchored primer
# 3 - right serovar anchored primer
# 4 - neither side has serovar primer, ignore this kind of SNP

    for left_snp_index, right_snp_index in product(interval_left_serovar_snps, interval_right_serovar_snps):
        print("fixed")
        #case 1
        right_snp_pos=vcf_data.loc[right_snp_index,"POS"]
        left_snp_pos=vcf_data.loc[left_snp_index,"POS"]
        if right_snp_pos-left_snp_pos>interval_len or right_snp_pos-left_snp_pos<min_interval_len: #distance between SNPs is too long:
            print(f'SNPs too far apart: {left_snp_pos} to {right_snp_pos} vs max len {str(interval_len)}')
            continue
        forward=ref_seq[left_snp_pos-1:left_snp_pos+20]
        reverse=ref_seq[right_snp_pos-20:right_snp_pos]
        seq_args={"SEQUENCE_ID":f'{target_lineage}_{str(snp_position)}', 
                "SEQUENCE_TEMPLATE": str(ref_seq[left_snp_pos-1:right_snp_pos].seq),
                "SEQUENCE_INCLUDED_REGION": [0, right_snp_pos-left_snp_pos+1 ]}
        #add "fixed" to name to show that this pair has both sides fixed
        global_args=add_fixed_primer(for_seq=str(forward.seq),rev_seq=str(reverse.seq.reverse_complement()), template=seq_args["SEQUENCE_TEMPLATE"])
        primers=primer3.bindings.design_primers(seq_args=seq_args, global_args=global_args)
        new_primer_pairs += process_p3_output(primers, id_prefix=f'{target_lineage}_{snp_position}_both_fixed')

    for right_snp_index in interval_right_serovar_snps:
        print("right")
        right_snp_pos=vcf_data.loc[right_snp_index,"POS"]
        reverse=ref_seq[right_snp_pos-20:right_snp_pos]
        seq_args={"SEQUENCE_ID":f'{target_lineage}_{str(snp_position)}', 
                "SEQUENCE_TEMPLATE": str(ref_seq[right_snp_pos-interval_len:right_snp_pos].seq),
                "SEQUENCE_INCLUDED_REGION": [0, interval_len ]}
        global_args=add_fixed_primer(for_seq=None,rev_seq=str(reverse.seq.reverse_complement()),  template=seq_args["SEQUENCE_TEMPLATE"])
        primers=primer3.bindings.design_primers(seq_args=seq_args, global_args=global_args)
        new_primer_pairs += process_p3_output(primers, id_prefix=f'{target_lineage}_{snp_position}_right_fixed')

    for left_snp_index in interval_left_serovar_snps:
        print("left")
        left_snp_pos=vcf_data.loc[left_snp_index,"POS"]
        forward=ref_seq[left_snp_pos-1:left_snp_pos+20] #-1 due to VCF being 1 indexed
        seq_args={"SEQUENCE_ID":f'{target_lineage}_{str(snp_position)}', 
                "SEQUENCE_TEMPLATE": str(ref_seq[left_snp_pos-20:left_snp_pos+interval_len].seq),
                "SEQUENCE_INCLUDED_REGION": [0, interval_len ]}
        global_args=add_fixed_primer(for_seq=str(forward.seq), rev_seq=None, template=seq_args["SEQUENCE_TEMPLATE"])
        primers=primer3.bindings.design_primers(seq_args=seq_args, global_args=global_args)
        new_primer_pairs += process_p3_output(primers, id_prefix=f'{target_lineage}_{snp_position}_both_fixed')

#sometimes the same pair of F/R sequences is generated multiple times because there are multiple species SNPs around same genotype SNP
unique_new_primer_pairs: List[PrimerPair]=[]
existing_sequences=set()
for pair in new_primer_pairs:
    sequences=pair.forward.seq+"_"+pair.reverse.seq
    if sequences not in existing_sequences:
        unique_new_primer_pairs.append(pair)
        existing_sequences.add(sequences)
# Out:
# SNP at 27750 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 34652 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# LEFT: considered 12207, GC content failed 1499, low tm 1913, high tm 116, high hairpin stability 2, long poly-x seq 262, ok 8415
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 12207, GC content failed 1499, low tm 1913, high tm 116, high hairpin stability 2, long poly-x seq 262, ok 8415
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 12479, GC content failed 1651, low tm 2090, high tm 142, high hairpin stability 1, long poly-x seq 223, ok 8372
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# left
# left
# SNP at 36076 has serovar SNPs left of genotype SNP
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13570, GC content failed 1126, low tm 1794, high tm 417, high hairpin stability 1, long poly-x seq 64, ok 10168
# PAIR: considered 5, ok 5
#
#
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 14010, GC content failed 60, low tm 1182, high tm 539, ok 12229
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 14010, GC content failed 60, low tm 1182, high tm 539, ok 12229
# PAIR: considered 5, ok 5
#
#
# SNP at 186367 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# right
# left
# left
# SNP at 207197 has serovar SNPs left of genotype SNP
# left
# left
# left
# left
# SNP at 262651 has serovar SNPs left of genotype SNP
# left
# SNP at 316186 has serovar SNPs left and right of genotype SNP
# fixed
# SNPs too far apart: 315236 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315236 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315236 to 317362 vs max len 1500
# fixed
# SNPs too far apart: 315237 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315237 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315237 to 317362 vs max len 1500
# fixed
# SNPs too far apart: 315238 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315238 to 316812 vs max len 1500
# fixed
# SNPs too far apart: 315238 to 317362 vs max len 1500
# right
# right
# right
# LEFT: considered 13710, GC content failed 136, low tm 212, high tm 2093, high hairpin stability 1, long poly-x seq 44, ok 11224
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 13710, GC content failed 136, low tm 212, high tm 2093, high hairpin stability 1, long poly-x seq 44, ok 11224
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# left
# left
# left
# SNP at 360661 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# left
# SNP at 410636 has no serovar SNPs within 1500 region
# SNP at 461867 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# SNPs too far apart: 461132 to 462834 vs max len 1500
# fixed
# SNPs too far apart: 461851 to 461883 vs max len 1500
# fixed
# fixed
# SNPs too far apart: 461852 to 461883 vs max len 1500
# fixed
# fixed
# SNPs too far apart: 461855 to 461883 vs max len 1500
# fixed
# fixed
# SNPs too far apart: 461855 to 461883 vs max len 1500
# fixed
# right
# right
# left
# left
# left
# left
# left
# SNP at 511709 has serovar SNPs left of genotype SNP
# left
# left
# SNP at 522454 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# right
# right
# right
# left
# SNP at 547113 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# LEFT: considered 13563, GC content failed 388, low tm 736, high tm 1733, high hairpin stability 2, long poly-x seq 66, ok 10638
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# right
# LEFT: considered 13563, GC content failed 362, low tm 744, high tm 1600, high hairpin stability 1, long poly-x seq 66, ok 10790
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13563, GC content failed 363, low tm 774, high tm 1537, high hairpin stability 1, long poly-x seq 66, ok 10822
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# left
# left
# left
# left
# SNP at 553578 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 646727 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# left
# left
# left
# left
# left
# left
# left
# left
# SNP at 665780 has serovar SNPs right of genotype SNP
# right
# right
# right
# right
# LEFT: considered 13731, GC content failed 242, low tm 420, high tm 1899, high hairpin stability 1, long poly-x seq 42, ok 11127
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# SNP at 681458 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 708639 has serovar SNPs left of genotype SNP
# left
# SNP at 734886 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# SNPs too far apart: 734181 to 735812 vs max len 1500
# fixed
# fixed
# right
# right
# left
# left
# SNP at 860662 has no serovar SNPs within 1500 region
# SNP at 885304 has serovar SNPs right of genotype SNP
# right
# SNP at 909756 has serovar SNPs right of genotype SNP
# right
# SNP at 925998 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# right
# right
# right
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 14010, GC content failed 218, low tm 239, high tm 1805, high hairpin stability 1, ok 11747
# PAIR: considered 5, ok 5
#
#
# SNP at 936428 has serovar SNPs left of genotype SNP
# left
# SNP at 952954 has serovar SNPs right of genotype SNP
# right
# right
# LEFT: considered 14010, GC content failed 218, low tm 327, high tm 1887, ok 11578
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 14010, GC content failed 218, low tm 327, high tm 1887, ok 11578
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# SNP at 964440 has serovar SNPs right of genotype SNP
# right
# right
# right
# SNP at 1139189 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 1175913 has serovar SNPs left of genotype SNP
# left
# SNP at 1286653 has serovar SNPs left of genotype SNP
# left
# SNP at 1299540 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# right
# right
# left
# SNP at 1326418 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# right
# right
# right
# left
# SNP at 1328974 has serovar SNPs left of genotype SNP
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13458, GC content failed 263, low tm 530, high tm 1548, high hairpin stability 1, long poly-x seq 86, ok 11030
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13458, GC content failed 263, low tm 530, high tm 1548, high hairpin stability 1, long poly-x seq 86, ok 11030
# PAIR: considered 5, ok 5
#
#
# SNP at 1411230 has serovar SNPs right of genotype SNP
# right
# right
# SNP at 1432909 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# SNPs too far apart: 1431896 to 1433622 vs max len 1500
# right
# right
# right
# left
# SNP at 1505479 has serovar SNPs left and right of genotype SNP
# fixed
# SNPs too far apart: 1504444 to 1506436 vs max len 1500
# fixed
# SNPs too far apart: 1504618 to 1506436 vs max len 1500
# fixed
# right
# left
# left
# left
# SNP at 1700099 has serovar SNPs right of genotype SNP
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# SNP at 1818219 has serovar SNPs left and right of genotype SNP
# fixed
# SNPs too far apart: 1817270 to 1819051 vs max len 1500
# fixed
# SNPs too far apart: 1817341 to 1819051 vs max len 1500
# fixed
# SNPs too far apart: 1817349 to 1819051 vs max len 1500
# fixed
# right
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13857, GC content failed 435, low tm 310, high tm 2525, high hairpin stability 6, long poly-x seq 22, ok 10559
# PAIR: considered 5, ok 5
#
#
# left
# SNP at 1826640 has serovar SNPs left of genotype SNP
# left
# left
# SNP at 1873385 has serovar SNPs left of genotype SNP
# left
# SNP at 1881601 has serovar SNPs right of genotype SNP
# right
# SNP at 2070766 has no serovar SNPs within 1500 region
# SNP at 2103045 has no serovar SNPs within 1500 region
# SNP at 2125378 has serovar SNPs left of genotype SNP
# left
# left
# SNP at 2160827 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# SNPs too far apart: 2160144 to 2161749 vs max len 1500
# fixed
# fixed
# fixed
# SNPs too far apart: 2160144 to 2161749 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 2160771 to 2160859 vs max len 1500
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# SNPs too far apart: 2160771 to 2160859 vs max len 1500
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# SNPs too far apart: 2160807 to 2160859 vs max len 1500
# fixed
# SNPs too far apart: 2160807 to 2160993 vs max len 1500
# fixed
# right
# LEFT: considered 13575, GC content failed 114, low tm 493, high tm 1288, high hairpin stability 2, long poly-x seq 67, ok 11611
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 13575, GC content failed 114, low tm 493, high tm 1288, high hairpin stability 2, long poly-x seq 67, ok 11611
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13575, GC content failed 132, low tm 619, high tm 1197, high hairpin stability 3, long poly-x seq 67, ok 11557
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# left
# left
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13857, GC content failed 589, low tm 857, high tm 1067, high hairpin stability 3, long poly-x seq 22, ok 11319
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13857, GC content failed 589, low tm 857, high tm 1067, high hairpin stability 3, long poly-x seq 22, ok 11319
# PAIR: considered 5, ok 5
#
#
# left
# SNP at 2195467 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# SNPs too far apart: 2194518 to 2196100 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# right
# right
# LEFT: considered 13120, GC content failed 859, low tm 1470, high tm 429, high hairpin stability 4, long poly-x seq 134, ok 10224
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 13120, GC content failed 859, low tm 1470, high tm 429, high hairpin stability 4, long poly-x seq 134, ok 10224
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 13120, GC content failed 859, low tm 1470, high tm 429, high hairpin stability 4, long poly-x seq 134, ok 10224
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# left
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13373, GC content failed 297, low tm 667, high tm 1054, high hairpin stability 3, long poly-x seq 95, ok 11257
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13373, GC content failed 297, low tm 667, high tm 1054, high hairpin stability 3, long poly-x seq 95, ok 11257
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13373, GC content failed 297, low tm 667, high tm 1054, high hairpin stability 3, long poly-x seq 95, ok 11257
# PAIR: considered 5, ok 5
#
#
# left
# SNP at 2220836 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 2219851 to 2221582 vs max len 1500
# fixed
# SNPs too far apart: 2219851 to 2221582 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# right
# right
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13864, GC content failed 54, low tm 324, high tm 1436, high hairpin stability 1, long poly-x seq 22, ok 12027
# PAIR: considered 5, ok 5
#
#
# left
# left
# SNP at 2255824 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# right
# right
# left
# left
# SNP at 2463292 has serovar SNPs right of genotype SNP
# right
# right
# LEFT: considered 13975, GC content failed 715, low tm 2865, high tm 11, high hairpin stability 1, long poly-x seq 6, ok 10377
# RIGHT: considered 1, ok 1
# PAIR: considered 6, ok 6
#
#
# LEFT: considered 13975, GC content failed 715, low tm 2865, high tm 11, high hairpin stability 1, long poly-x seq 6, ok 10377
# RIGHT: considered 1, ok 1
# PAIR: considered 6, ok 6
#
#
# LEFT: considered 13975, GC content failed 715, low tm 2865, high tm 11, high hairpin stability 1, long poly-x seq 6, ok 10377
# RIGHT: considered 1, ok 1
# PAIR: considered 6, ok 6
#
#
# right
# right
# SNP at 2526712 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# right
# left
# left
# SNP at 2615810 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# left
# left
# left
# left
# left
# SNP at 2631711 has serovar SNPs right of genotype SNP
# right
# right
# SNP at 2660563 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 2728508 has no serovar SNPs within 1500 region
# SNP at 2801118 has serovar SNPs left and right of genotype SNP
# fixed
# SNPs too far apart: 2799780 to 2801281 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2801617 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2802056 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2801281 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2801617 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2802056 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2801281 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2801617 vs max len 1500
# fixed
# SNPs too far apart: 2799780 to 2802056 vs max len 1500
# fixed
# fixed
# fixed
# SNPs too far apart: 2800451 to 2802056 vs max len 1500
# fixed
# fixed
# fixed
# SNPs too far apart: 2800451 to 2802056 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 2801108 to 2801281 vs max len 1500
# fixed
# fixed
# right
# right
# right
# left
# left
# left
# left
# left
# left
# left
# left
# left
# SNP at 2813960 has serovar SNPs left of genotype SNP
# left
# SNP at 2839812 has serovar SNPs left of genotype SNP
# left
# SNP at 2878049 has no serovar SNPs within 1500 region
# SNP at 2891240 has no serovar SNPs within 1500 region
# SNP at 2946197 has no serovar SNPs within 1500 region
# SNP at 3013384 has serovar SNPs right of genotype SNP
# right
# right
# right
# right
# right
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 92, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12174
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 93, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12173
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 94, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12172
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 95, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12171
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 96, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12170
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 97, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12169
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 98, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12168
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 99, high tm 1563, high hairpin stability 2, long poly-x seq 22, ok 12167
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# right
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1560, high hairpin stability 2, long poly-x seq 22, ok 12168
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1557, high hairpin stability 2, long poly-x seq 22, ok 12171
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1553, high hairpin stability 2, long poly-x seq 22, ok 12175
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1551, high hairpin stability 2, long poly-x seq 22, ok 12177
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1548, high hairpin stability 2, long poly-x seq 22, ok 12180
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1547, high hairpin stability 2, long poly-x seq 22, ok 12181
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1547, high hairpin stability 2, long poly-x seq 22, ok 12181
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# LEFT: considered 13857, GC content failed 4, low tm 101, high tm 1547, high hairpin stability 2, long poly-x seq 22, ok 12181
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# LEFT: considered 13704, GC content failed 5, low tm 390, high tm 973, high hairpin stability 3, long poly-x seq 44, ok 12289
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# SNP at 3038753 has serovar SNPs left of genotype SNP
# left
# SNP at 3048613 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# left
# left
# left
# left
# left
# SNP at 3048757 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# left
# left
# left
# left
# left
# SNP at 3064412 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# right
# left
# left
# left
# SNP at 3064413 has serovar SNPs left of genotype SNP
# left
# left
# left
# left
# SNP at 3083090 has serovar SNPs right of genotype SNP
# right
# SNP at 3089267 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13245, GC content failed 86, low tm 278, high tm 2443, high hairpin stability 2, long poly-x seq 110, ok 10326
# PAIR: considered 8, unacceptable product size 2, ok 6
#
#
# SNP at 3154948 has serovar SNPs right of genotype SNP
# right
# LEFT: considered 14010, GC content failed 96, low tm 256, high tm 1752, ok 11906
# RIGHT: considered 1, ok 1
# PAIR: considered 6, ok 6
#
#
# SNP at 3237108 has serovar SNPs right of genotype SNP
# right
# right
# right
# SNP at 3242081 has serovar SNPs left of genotype SNP
# left
# left
# left
# left
# SNP at 3284725 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# SNPs too far apart: 3283960 to 3285467 vs max len 1500
# fixed
# SNPs too far apart: 3283960 to 3285467 vs max len 1500
# fixed
# fixed
# fixed
# SNPs too far apart: 3283960 to 3285467 vs max len 1500
# fixed
# SNPs too far apart: 3283960 to 3285467 vs max len 1500
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# right
# left
# left
# left
# left
# SNP at 3379604 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# right
# left
# SNP at 3415394 has serovar SNPs left and right of genotype SNP
# fixed
# right
# left
# SNP at 3416074 has serovar SNPs left and right of genotype SNP
# fixed
# fixed
# SNPs too far apart: 3414763 to 3417033 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417034 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417035 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417036 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417037 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417038 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417039 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417040 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417041 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417042 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417043 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417044 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417045 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417046 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417047 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417053 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417054 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417056 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417057 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417058 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417059 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417060 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417061 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417062 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417063 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417064 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417065 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417066 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417067 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417068 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417069 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417070 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417071 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417072 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417073 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417074 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417075 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417076 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417077 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417078 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417079 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417080 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417081 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417082 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417083 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417084 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417085 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417086 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417087 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417088 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417089 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417090 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417091 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417092 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417093 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417094 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417095 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417096 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417097 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417098 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417099 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417100 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417101 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417102 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417103 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417104 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417105 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417106 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417112 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417114 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417117 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417120 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417121 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417127 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417128 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417129 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417130 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417133 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417133 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417135 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417138 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417138 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417139 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417144 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417145 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417162 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417162 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417163 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417163 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417170 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417171 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417172 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417173 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417174 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417175 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417176 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417177 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417178 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417179 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417180 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417181 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417182 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417183 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417184 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417185 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417186 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417187 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417188 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417188 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417198 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417199 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417200 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417201 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417202 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417203 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417204 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417205 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417206 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417207 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417208 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417209 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417210 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417211 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417212 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417213 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417214 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417215 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417216 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417217 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417218 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417219 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417220 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417221 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417222 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417223 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417224 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417225 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417226 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417227 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417228 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417229 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417230 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417231 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417232 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417233 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417234 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417235 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417236 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417237 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417238 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417239 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417240 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417241 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417242 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417243 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417244 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417245 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417246 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417247 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417248 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417249 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417250 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417251 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417252 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417253 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417254 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417255 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417256 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417257 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417258 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417259 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417260 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417261 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417262 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417263 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417264 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417265 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417266 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417267 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417268 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417269 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417270 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417271 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417272 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417273 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417274 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417275 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417276 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417277 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417278 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417279 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417280 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417281 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417282 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417283 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417284 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417285 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417286 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417287 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417288 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417289 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417290 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417291 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417292 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417293 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417294 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417295 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417296 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417297 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417298 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417299 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417300 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417301 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417302 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417303 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417304 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417305 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417306 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417307 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417308 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417309 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417310 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417311 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417312 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417313 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417315 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417316 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417338 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417339 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417340 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417341 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417342 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417343 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417344 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417345 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417346 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417347 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417348 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417349 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417350 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417351 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417352 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417364 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417365 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417366 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417367 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417368 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417369 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417370 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417371 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417372 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417373 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417374 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417375 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417376 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417377 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417378 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417379 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417380 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417381 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417382 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417383 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417384 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417385 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417386 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417387 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417388 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417389 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417390 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417391 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417392 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417393 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417394 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417395 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417396 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417397 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417398 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417399 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417400 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417401 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417402 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417403 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417404 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417405 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417406 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417407 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417408 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417409 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417410 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417411 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417412 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417413 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417414 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417415 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417416 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417417 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417418 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417419 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417420 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417421 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417422 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417423 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417424 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417425 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417426 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417427 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417428 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417429 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417430 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417431 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417432 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417433 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417434 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417435 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417436 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417437 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417438 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417439 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417440 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417441 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417450 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417450 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417450 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417454 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417454 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417455 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417456 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417457 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417458 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417459 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417460 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417461 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417462 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417463 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417464 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417465 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417466 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417467 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417468 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417469 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417470 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417471 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417472 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417473 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417475 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417476 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417476 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417479 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417479 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417479 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417482 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417483 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417483 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417485 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417485 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417487 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417490 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417491 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417493 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417494 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417496 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417498 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417498 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417499 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417500 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417501 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417502 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417502 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417504 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417505 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417506 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417507 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417508 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417510 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417516 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417516 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417519 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417519 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417519 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417524 vs max len 1500
# fixed
# SNPs too far apart: 3414763 to 3417527 vs max len 1500
# fixed
# ...
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# SNPs too far apart: 4520580 to 4522085 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522088 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522115 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522115 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522130 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522132 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522136 vs max len 1500
# fixed
# SNPs too far apart: 4520580 to 4522139 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4520616 to 4522130 vs max len 1500
# fixed
# SNPs too far apart: 4520616 to 4522132 vs max len 1500
# fixed
# SNPs too far apart: 4520616 to 4522136 vs max len 1500
# fixed
# SNPs too far apart: 4520616 to 4522139 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4521133 to 4521167 vs max len 1500
# fixed
# SNPs too far apart: 4521133 to 4521192 vs max len 1500
# fixed
# SNPs too far apart: 4521133 to 4521272 vs max len 1500
# fixed
# SNPs too far apart: 4521133 to 4521297 vs max len 1500
# fixed
# SNPs too far apart: 4521133 to 4521322 vs max len 1500
# fixed
# SNPs too far apart: 4521133 to 4521323 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4521152 to 4521167 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521192 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521272 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521297 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521322 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521323 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521339 vs max len 1500
# fixed
# SNPs too far apart: 4521152 to 4521342 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4521164 to 4521167 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521192 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521272 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521297 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521322 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521323 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521339 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521342 vs max len 1500
# fixed
# SNPs too far apart: 4521164 to 4521360 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4521165 to 4521167 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521192 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521272 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521297 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521322 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521323 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521339 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521342 vs max len 1500
# fixed
# SNPs too far apart: 4521165 to 4521360 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# SNPs too far apart: 4521166 to 4521167 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521192 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521272 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521297 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521322 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521323 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521339 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521342 vs max len 1500
# fixed
# SNPs too far apart: 4521166 to 4521360 vs max len 1500
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# fixed
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# right
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 298, low tm 1849, high tm 148, long poly-x seq 45, ok 11363
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 298, low tm 1830, high tm 148, high hairpin stability 3, long poly-x seq 45, ok 11379
# PAIR: considered 9, unacceptable product size 4, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 298, low tm 1830, high tm 148, high hairpin stability 3, long poly-x seq 45, ok 11379
# PAIR: considered 9, unacceptable product size 4, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 298, low tm 1830, high tm 148, high hairpin stability 3, long poly-x seq 45, ok 11379
# PAIR: considered 9, unacceptable product size 4, ok 5
#
#
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 294, low tm 1699, high tm 183, high hairpin stability 4, long poly-x seq 45, ok 11478
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 294, low tm 1699, high tm 183, high hairpin stability 4, long poly-x seq 45, ok 11478
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 294, low tm 1699, high tm 183, high hairpin stability 4, long poly-x seq 45, ok 11478
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13703, GC content failed 294, low tm 1699, high tm 183, high hairpin stability 4, long poly-x seq 45, ok 11478
# PAIR: considered 5, ok 5
#
#
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13742, GC content failed 324, low tm 1708, high tm 208, high hairpin stability 7, long poly-x seq 44, ok 11451
# PAIR: considered 6, unacceptable product size 1, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13742, GC content failed 324, low tm 1708, high tm 208, high hairpin stability 7, long poly-x seq 44, ok 11451
# PAIR: considered 6, unacceptable product size 1, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13742, GC content failed 324, low tm 1708, high tm 208, high hairpin stability 7, long poly-x seq 44, ok 11451
# PAIR: considered 6, unacceptable product size 1, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13742, GC content failed 324, low tm 1708, high tm 208, high hairpin stability 7, long poly-x seq 44, ok 11451
# PAIR: considered 6, unacceptable product size 1, ok 5
#
#
# left
# left
# left
# left
# left
# left
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# left
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# LEFT: considered 1, ok 1
# RIGHT: considered 13887, GC content failed 224, low tm 1726, high tm 237, high hairpin stability 5, long poly-x seq 22, ok 11673
# PAIR: considered 5, ok 5
#
#
# SNP at 4585827 has serovar SNPs right of genotype SNP
# right
# LEFT: considered 13695, GC content failed 54, low tm 332, high tm 1667, high hairpin stability 2, long poly-x seq 45, ok 11595
# RIGHT: considered 1, ok 1
# PAIR: considered 5, ok 5
#
#
# SNP at 4808250 has serovar SNPs right of genotype SNP
# right

# %%
len(new_primer_pairs)
# Out:
# 15850

# %%
interval_len=1000
new_primer_pairs: List[PrimerPair] = []
rev_straight="TGAGTCCGGTAAAACGAGCTC"
rev_seq=Seq(rev_straight[-20:]).reverse_complement()
#rev_straight=rev_straight[-20:]
for_straight="TGCAAGCTGCTTAGTGATCGA"
#for_straight=for_straight[0:20]
rev_pos=str(ref_seq.seq).find(str(rev_seq))+len(rev_straight)
for_pos=str(ref_seq.seq).find(for_straight)

seq_args={"SEQUENCE_ID":f'parC', 
        "SEQUENCE_TEMPLATE": str(ref_seq[for_pos-1:rev_pos+200].seq),
        "SEQUENCE_INCLUDED_REGION": [0, rev_pos-for_pos+200 ]}

global_args=add_fixed_primer(for_seq=for_straight[0:20],rev_seq=str(rev_seq.reverse_complement()),  template=seq_args["SEQUENCE_TEMPLATE"])
primers=primer3.bindings.design_primers(seq_args=seq_args, global_args=global_args)
new_primer_pairs += process_p3_output(primers, id_prefix=f'parC_left_fixed')
print(primers["PRIMER_PAIR_0_PRODUCT_SIZE"])
# Out:
# LEFT: considered 1, ok 1
# RIGHT: considered 1, ok 1
# PAIR: considered 1, ok 1
#
#
# 841

# %%
with open(f'{root_dir}HandyAmpliconTool/test_data/outputs/new_primer.tsv', "w") as output:
    for pair in min_penalty_pairs:
        output.write(pair.value+"\n")
        print(pair.penalty)
# Out:
# 0.5512316707744276
# 0.5534699146223829
# 0.5569654140309126
# 0.6253644260896749
# 0.6257255372350414
